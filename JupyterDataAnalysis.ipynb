# %% [markdown]
# LOADING CSV DATA to Jupyter
# ----------------------------------------------------------------
#
# NOTES:
# -------
# * With Jupyter you do not have to use print() to print data. Just call the variable/function that the data is stored in

# %%
import pandas as pd

df1= pd.read_csv("files/supermarkets.csv")

# %% [markdown]
# Loading JSON Data
# ----------------------------------------------------------------

# %%
df2 = pd.read_json("files/supermarkets.json")

# %% [markdown]
# LOADING XLSX & Excel files
# ----------------------------------------------------------------
#
# NOTES:
# ------
# * You need to specify the sheet name when reading the Excel file -- ("/filepathname",sheet_name = the_index_of_sheet) i.e (1,2,3,4,5,6,7,8)

# %%
df3 = pd.read_excel("files/supermarkets.xlsx",sheet_name=0)

# %%
df4 = pd.read_csv("files/supermarkets-commas.txt")

# %% [markdown]
# Loading TXT files - they have a separator that's different from the default comma
# ---------------------------------------------------------------------------------

# %%
df5 = pd.read_csv("files/supermarkets-semi-colons.txt", sep=';')

# %% [markdown]
# Setting Table Header Row
# -------------------------
#
# * If you do not have a table header, you have to state that to Python ("filepathname",header=None)

# %%
df6 = pd.read_csv("files/data.txt", header = None)
df6
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
#Columns have to put it in a list and in the order of the data [USE THE INDEX NOT THE VALUES YOU SEE AT THE TOP]
df6.columns = ["ID", "Address", "City", "PostalCode", "Country", "Name", "Employee"]
df6
# Out:
#    ID          Address           City        PostalCode Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employee
# 0         8
# 1        15
# 2        25
# 3        10
# 4        12
# 5        20

# %% [markdown]
# Setting INDEX COLUMN
# ---------------------

# %%
df6.set_index("ID")
df6
# Out:
#    ID          Address           City        PostalCode Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employee
# 0         8
# 1        15
# 2        25
# 3        10
# 4        12
# 5        20

# %%
df6.set_index("Name", inplace = True, drop=False)
df6

#Be very careful when setting index ~ inplace = Drops all the other rows before the indexed column ADD: drop =False to keep the old data
# Out:
#              ID          Address           City        PostalCode Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employee
# Name
#  Madeira         Madeira         8
# Bready Shop  Bready Shop        15
# Super River  Super River        25
# Ben's Shop    Ben's Shop        10
# Sanchez          Sanchez        12
# Richvalley    Richvalley        20

# %% [markdown]
# Extracting Data
# ----------------------------------------------------------------

# %%
df6.iloc[3:,0:]
# Out:
#             ID          Address           City  PostalCode Country  \
# Name
# Ben's Shop   4     3995 23rd St  San Francisco    CA 94114     USA
# Sanchez      5  1056 Sanchez St  San Francisco  California     USA
# Richvalley   6  551 Alvarado St  San Francisco    CA 94114     USA
#
#                   Name  Employee
# Name
# Ben's Shop  Ben's Shop        10
# Sanchez        Sanchez        12
# Richvalley  Richvalley        20

# %%
df6_dict = dict(df6.iloc[3:,0:])
#print("This are the values of the dictionary")
#df6_dict.keys()

#print("This are the values of the dictionary")
#df6_dict.values()

df6
# Out:
#              ID          Address           City        PostalCode Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employee
# Name
#  Madeira         Madeira         8
# Bready Shop  Bready Shop        15
# Super River  Super River        25
# Ben's Shop    Ben's Shop        10
# Sanchez          Sanchez        12
# Richvalley    Richvalley        20

# %% [markdown]
# Deleting Columns and Rows
# ----------------------------------------------------------------

# %%
df6
df7 = df6
df7
#
df7.drop(df7.columns[0:-4],1)
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp\ipykernel_28028\3269542479.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df7.drop(df7.columns[0:-4],1)
#                    PostalCode Country         Name  Employee
# Name
#  Madeira             CA 94114     USA      Madeira         8
# Bready Shop          CA 94119     USA  Bready Shop        15
# Super River  California 94114     USA  Super River        25
# Ben's Shop           CA 94114     USA   Ben's Shop        10
# Sanchez            California     USA      Sanchez        12
# Richvalley           CA 94114     USA   Richvalley        20

# %% [markdown]
# Updating Columns and Rows
# ----------------------------------------------------------------

# %%
len(df6.index)
# Out:
# 6

# %%
#Adding a new column to the Data Frame

len(df6.index)
df6["Continent"] = df6.shape[0]*["North America"]

df6
# Out:
#              ID          Address           City        PostalCode Country  \
# Name
#  Madeira      1     3666 21st St  San Francisco          CA 94114     USA
# Bready Shop   2   735 Dolores St  San Francisco          CA 94119     USA
# Super River   3      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop    4     3995 23rd St  San Francisco          CA 94114     USA
# Sanchez       5  1056 Sanchez St  San Francisco        California     USA
# Richvalley    6  551 Alvarado St  San Francisco          CA 94114     USA
#
#                     Name  Employee      Continent
# Name
#  Madeira         Madeira         8  North America
# Bready Shop  Bready Shop        15  North America
# Super River  Super River        25  North America
# Ben's Shop    Ben's Shop        10  North America
# Sanchez          Sanchez        12  North America
# Richvalley    Richvalley        20  North America
